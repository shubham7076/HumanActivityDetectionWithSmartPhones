# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham7076/HumanActivityDetectionWithSmartPhones/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <H2> Apply t-sne on the data<H2>

# %% [markdown]
# Here we will see these datapoints in 2 dimensions and try to observe the behaviour of the datapoints

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=3000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity'], axis=1)
y_pre_tsne = train['Activity']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[5,10,20,30,50])
# Out:
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.804s...
# [t-SNE] Computed neighbors for 7352 samples in 31.743s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.039s
# [t-SNE] Iteration 50: error = 114.0279617, gradient norm = 0.0203088 (50 iterations in 1.567s)
# [t-SNE] Iteration 100: error = 97.3408661, gradient norm = 0.0147870 (50 iterations in 1.232s)
# [t-SNE] Iteration 150: error = 93.0467453, gradient norm = 0.0088418 (50 iterations in 1.114s)
# [t-SNE] Iteration 200: error = 91.1419678, gradient norm = 0.0083251 (50 iterations in 1.097s)
# [t-SNE] Iteration 250: error = 89.9888611, gradient norm = 0.0050227 (50 iterations in 1.108s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.988861
# [t-SNE] Iteration 300: error = 3.5740235, gradient norm = 0.0014677 (50 iterations in 1.085s)
# [t-SNE] Iteration 350: error = 2.8146791, gradient norm = 0.0007527 (50 iterations in 1.115s)
# [t-SNE] Iteration 400: error = 2.4329033, gradient norm = 0.0005196 (50 iterations in 1.102s)
# [t-SNE] Iteration 450: error = 2.2146227, gradient norm = 0.0004079 (50 iterations in 1.188s)
# [t-SNE] Iteration 500: error = 2.0694885, gradient norm = 0.0003322 (50 iterations in 1.200s)
# [t-SNE] Iteration 550: error = 1.9643260, gradient norm = 0.0002802 (50 iterations in 1.255s)
# [t-SNE] Iteration 600: error = 1.8833892, gradient norm = 0.0002453 (50 iterations in 1.185s)
# [t-SNE] Iteration 650: error = 1.8183650, gradient norm = 0.0002186 (50 iterations in 1.163s)
# [t-SNE] Iteration 700: error = 1.7645090, gradient norm = 0.0001991 (50 iterations in 1.184s)
# [t-SNE] Iteration 750: error = 1.7192738, gradient norm = 0.0001804 (50 iterations in 1.199s)
# [t-SNE] Iteration 800: error = 1.6804229, gradient norm = 0.0001645 (50 iterations in 1.180s)
# [t-SNE] Iteration 850: error = 1.6466731, gradient norm = 0.0001518 (50 iterations in 1.221s)
# [t-SNE] Iteration 900: error = 1.6169970, gradient norm = 0.0001429 (50 iterations in 1.189s)
# [t-SNE] Iteration 950: error = 1.5906878, gradient norm = 0.0001344 (50 iterations in 1.152s)
# [t-SNE] Iteration 1000: error = 1.5669905, gradient norm = 0.0001255 (50 iterations in 1.174s)
# [t-SNE] KL divergence after 1000 iterations: 1.566990
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\shubh\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.850s...
# [t-SNE] Computed neighbors for 7352 samples in 33.781s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.075s
# [t-SNE] Iteration 50: error = 106.0021439, gradient norm = 0.0142994 (50 iterations in 1.476s)
# [t-SNE] Iteration 100: error = 90.4900436, gradient norm = 0.0156645 (50 iterations in 1.306s)
# [t-SNE] Iteration 150: error = 87.3449936, gradient norm = 0.0058965 (50 iterations in 1.242s)
# [t-SNE] Iteration 200: error = 86.0847397, gradient norm = 0.0042853 (50 iterations in 1.278s)
# [t-SNE] Iteration 250: error = 85.3796616, gradient norm = 0.0027375 (50 iterations in 1.301s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.379662
# [t-SNE] Iteration 300: error = 3.1320715, gradient norm = 0.0013836 (50 iterations in 1.237s)
# [t-SNE] Iteration 350: error = 2.4899874, gradient norm = 0.0006509 (50 iterations in 1.184s)
# [t-SNE] Iteration 400: error = 2.1703868, gradient norm = 0.0004232 (50 iterations in 1.188s)
# [t-SNE] Iteration 450: error = 1.9856784, gradient norm = 0.0003156 (50 iterations in 1.200s)
# [t-SNE] Iteration 500: error = 1.8670728, gradient norm = 0.0002525 (50 iterations in 1.197s)
# [t-SNE] Iteration 550: error = 1.7835028, gradient norm = 0.0002130 (50 iterations in 1.212s)
# [t-SNE] Iteration 600: error = 1.7206706, gradient norm = 0.0001844 (50 iterations in 1.311s)
# [t-SNE] Iteration 650: error = 1.6716959, gradient norm = 0.0001591 (50 iterations in 1.263s)
# [t-SNE] Iteration 700: error = 1.6323138, gradient norm = 0.0001440 (50 iterations in 1.225s)
# [t-SNE] Iteration 750: error = 1.6002141, gradient norm = 0.0001311 (50 iterations in 1.238s)
# [t-SNE] Iteration 800: error = 1.5731072, gradient norm = 0.0001191 (50 iterations in 1.235s)
# [t-SNE] Iteration 850: error = 1.5500662, gradient norm = 0.0001090 (50 iterations in 1.225s)
# [t-SNE] Iteration 900: error = 1.5305963, gradient norm = 0.0001027 (50 iterations in 1.219s)
# [t-SNE] Iteration 950: error = 1.5132462, gradient norm = 0.0000977 (50 iterations in 1.218s)
# [t-SNE] Iteration 1000: error = 1.4982467, gradient norm = 0.0000921 (50 iterations in 1.220s)
# [t-SNE] KL divergence after 1000 iterations: 1.498247
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\shubh\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.815s...
# [t-SNE] Computed neighbors for 7352 samples in 33.353s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.142s
# [t-SNE] Iteration 50: error = 97.5481796, gradient norm = 0.0192916 (50 iterations in 1.464s)
# [t-SNE] Iteration 100: error = 84.3385849, gradient norm = 0.0063089 (50 iterations in 1.378s)
# [t-SNE] Iteration 150: error = 82.2558365, gradient norm = 0.0064671 (50 iterations in 1.344s)
# [t-SNE] Iteration 200: error = 81.4722519, gradient norm = 0.0028469 (50 iterations in 1.368s)
# [t-SNE] Iteration 250: error = 81.0581665, gradient norm = 0.0021951 (50 iterations in 1.382s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.058167
# [t-SNE] Iteration 300: error = 2.7243111, gradient norm = 0.0012919 (50 iterations in 1.327s)
# [t-SNE] Iteration 350: error = 2.1907609, gradient norm = 0.0005790 (50 iterations in 1.305s)
# [t-SNE] Iteration 400: error = 1.9403707, gradient norm = 0.0003479 (50 iterations in 1.333s)
# [t-SNE] Iteration 450: error = 1.7933202, gradient norm = 0.0002503 (50 iterations in 1.336s)
# [t-SNE] Iteration 500: error = 1.6987079, gradient norm = 0.0002001 (50 iterations in 1.353s)
# [t-SNE] Iteration 550: error = 1.6342239, gradient norm = 0.0001631 (50 iterations in 1.371s)
# [t-SNE] Iteration 600: error = 1.5876218, gradient norm = 0.0001373 (50 iterations in 1.366s)
# [t-SNE] Iteration 650: error = 1.5522456, gradient norm = 0.0001211 (50 iterations in 1.357s)
# [t-SNE] Iteration 700: error = 1.5247910, gradient norm = 0.0001085 (50 iterations in 1.356s)
# [t-SNE] Iteration 750: error = 1.5027320, gradient norm = 0.0000975 (50 iterations in 1.373s)
# [t-SNE] Iteration 800: error = 1.4847250, gradient norm = 0.0000905 (50 iterations in 1.364s)
# [t-SNE] Iteration 850: error = 1.4694890, gradient norm = 0.0000987 (50 iterations in 1.367s)
# [t-SNE] Iteration 900: error = 1.4570124, gradient norm = 0.0000797 (50 iterations in 1.368s)
# [t-SNE] Iteration 950: error = 1.4468085, gradient norm = 0.0000772 (50 iterations in 1.379s)
# [t-SNE] Iteration 1000: error = 1.4380944, gradient norm = 0.0000722 (50 iterations in 1.370s)
# [t-SNE] KL divergence after 1000 iterations: 1.438094
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\shubh\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 30 and with 1000 iterations at max
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.814s...
# [t-SNE] Computed neighbors for 7352 samples in 33.754s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.348516
# [t-SNE] Computed conditional probabilities in 0.215s
# [t-SNE] Iteration 50: error = 92.3171387, gradient norm = 0.0231089 (50 iterations in 1.587s)
# [t-SNE] Iteration 100: error = 80.3623505, gradient norm = 0.0046599 (50 iterations in 1.491s)
# [t-SNE] Iteration 150: error = 78.8649597, gradient norm = 0.0027884 (50 iterations in 1.460s)
# [t-SNE] Iteration 200: error = 78.3347168, gradient norm = 0.0018144 (50 iterations in 1.488s)
# [t-SNE] Iteration 250: error = 78.0649490, gradient norm = 0.0014065 (50 iterations in 1.507s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.064949
# [t-SNE] Iteration 300: error = 2.4590812, gradient norm = 0.0012713 (50 iterations in 1.471s)
# [t-SNE] Iteration 350: error = 1.9825677, gradient norm = 0.0005382 (50 iterations in 1.441s)
# [t-SNE] Iteration 400: error = 1.7698888, gradient norm = 0.0003220 (50 iterations in 1.440s)
# [t-SNE] Iteration 450: error = 1.6473635, gradient norm = 0.0002449 (50 iterations in 1.453s)
# [t-SNE] Iteration 500: error = 1.5678468, gradient norm = 0.0001721 (50 iterations in 1.474s)
# [t-SNE] Iteration 550: error = 1.5140049, gradient norm = 0.0001374 (50 iterations in 1.462s)
# [t-SNE] Iteration 600: error = 1.4753957, gradient norm = 0.0001172 (50 iterations in 1.462s)
# [t-SNE] Iteration 650: error = 1.4468386, gradient norm = 0.0001027 (50 iterations in 1.459s)
# [t-SNE] Iteration 700: error = 1.4258554, gradient norm = 0.0000931 (50 iterations in 1.470s)
# [t-SNE] Iteration 750: error = 1.4103653, gradient norm = 0.0000879 (50 iterations in 1.467s)
# [t-SNE] Iteration 800: error = 1.3984780, gradient norm = 0.0000802 (50 iterations in 1.465s)
# [t-SNE] Iteration 850: error = 1.3886886, gradient norm = 0.0000768 (50 iterations in 1.482s)
# [t-SNE] Iteration 900: error = 1.3804061, gradient norm = 0.0000736 (50 iterations in 1.473s)
# [t-SNE] Iteration 950: error = 1.3733406, gradient norm = 0.0000682 (50 iterations in 1.479s)
# [t-SNE] Iteration 1000: error = 1.3670372, gradient norm = 0.0000645 (50 iterations in 1.479s)
# [t-SNE] KL divergence after 1000 iterations: 1.367037
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\shubh\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.807s...
# [t-SNE] Computed neighbors for 7352 samples in 34.152s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.365s
# [t-SNE] Iteration 50: error = 85.6237640, gradient norm = 0.0291427 (50 iterations in 1.919s)
# [t-SNE] Iteration 100: error = 75.5696564, gradient norm = 0.0048341 (50 iterations in 1.839s)
# [t-SNE] Iteration 150: error = 74.6353531, gradient norm = 0.0024863 (50 iterations in 1.804s)
# [t-SNE] Iteration 200: error = 74.2914200, gradient norm = 0.0016337 (50 iterations in 1.859s)
# [t-SNE] Iteration 250: error = 74.1162567, gradient norm = 0.0012168 (50 iterations in 1.839s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.116257
# [t-SNE] Iteration 300: error = 2.1521549, gradient norm = 0.0011900 (50 iterations in 1.783s)
# [t-SNE] Iteration 350: error = 1.7560927, gradient norm = 0.0004845 (50 iterations in 1.701s)
# [t-SNE] Iteration 400: error = 1.5872259, gradient norm = 0.0002849 (50 iterations in 1.704s)
# [t-SNE] Iteration 450: error = 1.4937942, gradient norm = 0.0001896 (50 iterations in 1.708s)
# [t-SNE] Iteration 500: error = 1.4339042, gradient norm = 0.0001405 (50 iterations in 1.727s)
# [t-SNE] Iteration 550: error = 1.3925676, gradient norm = 0.0001131 (50 iterations in 1.727s)
# [t-SNE] Iteration 600: error = 1.3633816, gradient norm = 0.0000928 (50 iterations in 1.724s)
# [t-SNE] Iteration 650: error = 1.3422633, gradient norm = 0.0000824 (50 iterations in 1.725s)
# [t-SNE] Iteration 700: error = 1.3271616, gradient norm = 0.0000763 (50 iterations in 1.727s)
# [t-SNE] Iteration 750: error = 1.3162304, gradient norm = 0.0000716 (50 iterations in 1.740s)
# [t-SNE] Iteration 800: error = 1.3081561, gradient norm = 0.0000663 (50 iterations in 1.739s)
# [t-SNE] Iteration 850: error = 1.3015705, gradient norm = 0.0000628 (50 iterations in 1.770s)
# [t-SNE] Iteration 900: error = 1.2962642, gradient norm = 0.0000567 (50 iterations in 1.756s)
# [t-SNE] Iteration 950: error = 1.2916651, gradient norm = 0.0000565 (50 iterations in 1.746s)
# [t-SNE] Iteration 1000: error = 1.2876104, gradient norm = 0.0000547 (50 iterations in 1.762s)
# [t-SNE] KL divergence after 1000 iterations: 1.287610
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\shubh\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
